# %%
import os
import time
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.animation as animation
import scipy.io as scio

from dolfin import *
from fenics import *
import warnings

# %%
# Geubelle research group
# Authors:  Qibang Liu (qibang@illinois.edu)
#           Michael Zakoworotny (mjz7@illinois.edu)
#           Philippe Geubelle (geubelle@illinois.edu)
#           Aditya Kumar (aditya.kumar@ce.gatech.edu)
#
# An example of running the FP solver for DCPD

import os
from solver_FP import FP_solver
from kinetics_library import Prout_Tompkins_Diffusion
from postProcess_FP import Post_process, saveResults, loadResults


# Sam's imports
from scipy import interpolate as itp
from scipy.integrate import quad
from scipy import optimize


# Switch to current directory
try:
    os.chdir(os.path.dirname(__file__))
except:
    print("Cannot switch directories")

# Thermo-chemical properties
kr = 0.15      # thermal conductivity, W/m-K
rhor = 980.0    # density, kg/m^3
Cpr = 1600.0    # specific heat, J/kg-K

# Nature values
Hr = 350000    # enthalpy, J/kg
A_ = 8.55e15    # pre-exponential constant, 1/s
Er = 110750.0   # activation energy J/mol
n = 1.72        # cure kinetics parameter
m = 0.77        # cure kinetics parameter
Ca = 14.48      # cure kinetics parameter
alpha_c = 0.41  # cure kinetics parameter

# Create an object for the cure kinetics model
ptd_model = Prout_Tompkins_Diffusion(n, m, Ca, alpha_c)

# Initial conditions for temperature and degree of cure
T0 = 20         # deg C
alpha0 = 0.01

# Length of domain
L = 0.03

# Initialize the solver with the parameters
solver = FP_solver(kr, rhor, Cpr, Hr, A_, Er,
                   ptd_model, T0, alpha0, 0, 0.001, 0, L=L)

# Run the solver until 10 s
t_end = 150
results_data = solver.solve(
    t_end, outputFreq_t=10, outputFreq_x=1)

# %%
# Post-process - generate report, compute the front speed, and save an animation of the temperature and alpha fronts

save_dir = "out_DCPD"  # path to save the result files.
pts_ = [2e-3, 5e-3]  # Get evolution of alpha and T at this points
# create post process object
post_pro = Post_process(results_data, solver, pts=pts_,
                        save_dir=save_dir, save_suffix="DCPD", anim_frames=100, fid=0)
post_pro.generateReport()  # generate report

# %%
# Pack the results for future use
saveResults(results_data, save_dir, "data_DCPD")  # save to .mat file
loadedResults = loadResults(save_dir, "data_DCPD")  # load from .mat file
results_data = loadedResults
# Out:
# Cannot switch directories
# Saving results for t = 0.010000 s, Elapsed simulation time: 0.070686 s
# Saving results for t = 0.020000 s, Elapsed simulation time: 0.144859 s
# Saving results for t = 0.030000 s, Elapsed simulation time: 0.217946 s
# Saving results for t = 0.040000 s, Elapsed simulation time: 0.290720 s
# Saving results for t = 0.050000 s, Elapsed simulation time: 0.364131 s
# Saving results for t = 0.060000 s, Elapsed simulation time: 0.438222 s
# Saving results for t = 0.070000 s, Elapsed simulation time: 0.512057 s
# Saving results for t = 0.080000 s, Elapsed simulation time: 0.586023 s
# Saving results for t = 0.090000 s, Elapsed simulation time: 0.659639 s
# Saving results for t = 0.100000 s, Elapsed simulation time: 0.732497 s
# Saving results for t = 0.110000 s, Elapsed simulation time: 0.805818 s
# Saving results for t = 0.120000 s, Elapsed simulation time: 0.879746 s
# Saving results for t = 0.130000 s, Elapsed simulation time: 0.954657 s
# Saving results for t = 0.140000 s, Elapsed simulation time: 1.028969 s
# Saving results for t = 0.150000 s, Elapsed simulation time: 1.102143 s
# Saving results for t = 0.160000 s, Elapsed simulation time: 1.175080 s
# Saving results for t = 0.170000 s, Elapsed simulation time: 1.248356 s
# Saving results for t = 0.180000 s, Elapsed simulation time: 1.322382 s
# Saving results for t = 0.190000 s, Elapsed simulation time: 1.396393 s
# Saving results for t = 0.200000 s, Elapsed simulation time: 1.469275 s
# Saving results for t = 0.210000 s, Elapsed simulation time: 1.542369 s
# Saving results for t = 0.220000 s, Elapsed simulation time: 1.616680 s
# Saving results for t = 0.230000 s, Elapsed simulation time: 1.690522 s
# Saving results for t = 0.240000 s, Elapsed simulation time: 1.763462 s
# Saving results for t = 0.250000 s, Elapsed simulation time: 1.836313 s
# Saving results for t = 0.260000 s, Elapsed simulation time: 1.911607 s
# Saving results for t = 0.270000 s, Elapsed simulation time: 1.986115 s
# Saving results for t = 0.280000 s, Elapsed simulation time: 2.060273 s
# Saving results for t = 0.290000 s, Elapsed simulation time: 2.132935 s
# Saving results for t = 0.300000 s, Elapsed simulation time: 2.206435 s
# Saving results for t = 0.310000 s, Elapsed simulation time: 2.280049 s
# Saving results for t = 0.320000 s, Elapsed simulation time: 2.353856 s
# Saving results for t = 0.330000 s, Elapsed simulation time: 2.428098 s
# Saving results for t = 0.340000 s, Elapsed simulation time: 2.501951 s
# Saving results for t = 0.350000 s, Elapsed simulation time: 2.574609 s
# Saving results for t = 0.360000 s, Elapsed simulation time: 2.647633 s
# Saving results for t = 0.370000 s, Elapsed simulation time: 2.721498 s
# Saving results for t = 0.380000 s, Elapsed simulation time: 2.795611 s
# Saving results for t = 0.390000 s, Elapsed simulation time: 2.869685 s
# Saving results for t = 0.400000 s, Elapsed simulation time: 2.943266 s
# Saving results for t = 0.410000 s, Elapsed simulation time: 3.016798 s
# Saving results for t = 0.420000 s, Elapsed simulation time: 3.089663 s
# Saving results for t = 0.430000 s, Elapsed simulation time: 3.163319 s
# Saving results for t = 0.440000 s, Elapsed simulation time: 3.237110 s
# Saving results for t = 0.450000 s, Elapsed simulation time: 3.310533 s
# Saving results for t = 0.460000 s, Elapsed simulation time: 3.383209 s
# Saving results for t = 0.470000 s, Elapsed simulation time: 3.456887 s
# Saving results for t = 0.480000 s, Elapsed simulation time: 3.529979 s
# Saving results for t = 0.490000 s, Elapsed simulation time: 3.603610 s
# Saving results for t = 0.500000 s, Elapsed simulation time: 3.677145 s
# Saving results for t = 0.510000 s, Elapsed simulation time: 3.750876 s
# Saving results for t = 0.520000 s, Elapsed simulation time: 3.824841 s
# Saving results for t = 0.530000 s, Elapsed simulation time: 3.898746 s
# Saving results for t = 0.540000 s, Elapsed simulation time: 3.972502 s
# Saving results for t = 0.550000 s, Elapsed simulation time: 4.045737 s
# Saving results for t = 0.560000 s, Elapsed simulation time: 4.118750 s
# Saving results for t = 0.570000 s, Elapsed simulation time: 4.192525 s
# Saving results for t = 0.580000 s, Elapsed simulation time: 4.266246 s
# Saving results for t = 0.590000 s, Elapsed simulation time: 4.339297 s
# Saving results for t = 0.600000 s, Elapsed simulation time: 4.412356 s
# Saving results for t = 0.610000 s, Elapsed simulation time: 4.486199 s
# Saving results for t = 0.620000 s, Elapsed simulation time: 4.559676 s
# Saving results for t = 0.630000 s, Elapsed simulation time: 4.632646 s
# Saving results for t = 0.640000 s, Elapsed simulation time: 4.706304 s
# Saving results for t = 0.650000 s, Elapsed simulation time: 4.780406 s
# Saving results for t = 0.660000 s, Elapsed simulation time: 4.853402 s
# Saving results for t = 0.670000 s, Elapsed simulation time: 4.928317 s
# Saving results for t = 0.680000 s, Elapsed simulation time: 5.002940 s
# Saving results for t = 0.690000 s, Elapsed simulation time: 5.076684 s
# Saving results for t = 0.700000 s, Elapsed simulation time: 5.151263 s
# Saving results for t = 0.710000 s, Elapsed simulation time: 5.225169 s
# Saving results for t = 0.720000 s, Elapsed simulation time: 5.298690 s
# Saving results for t = 0.730000 s, Elapsed simulation time: 5.372174 s
# Saving results for t = 0.740000 s, Elapsed simulation time: 5.445904 s
# Saving results for t = 0.750000 s, Elapsed simulation time: 5.519875 s
# Saving results for t = 0.760000 s, Elapsed simulation time: 5.594119 s
# Saving results for t = 0.770000 s, Elapsed simulation time: 5.668325 s
# Saving results for t = 0.780000 s, Elapsed simulation time: 5.742487 s
# Saving results for t = 0.790000 s, Elapsed simulation time: 5.816842 s
# Saving results for t = 0.800000 s, Elapsed simulation time: 5.890199 s
# Saving results for t = 0.810000 s, Elapsed simulation time: 5.964353 s
# Saving results for t = 0.820000 s, Elapsed simulation time: 6.038709 s
# Saving results for t = 0.830000 s, Elapsed simulation time: 6.113013 s
# Saving results for t = 0.840000 s, Elapsed simulation time: 6.187552 s
# Saving results for t = 0.850000 s, Elapsed simulation time: 6.262399 s
# Saving results for t = 0.860000 s, Elapsed simulation time: 6.335996 s
# Saving results for t = 0.870000 s, Elapsed simulation time: 6.409590 s
# Saving results for t = 0.880000 s, Elapsed simulation time: 6.483329 s
# Saving results for t = 0.890000 s, Elapsed simulation time: 6.557956 s
# Saving results for t = 0.900000 s, Elapsed simulation time: 6.632609 s
# Saving results for t = 0.910000 s, Elapsed simulation time: 6.707223 s
# Saving results for t = 0.920000 s, Elapsed simulation time: 6.780469 s
# Saving results for t = 0.930000 s, Elapsed simulation time: 6.854052 s
# Saving results for t = 0.940000 s, Elapsed simulation time: 6.928392 s
# Saving results for t = 0.950000 s, Elapsed simulation time: 7.003445 s
# Saving results for t = 0.960000 s, Elapsed simulation time: 7.076652 s
# Saving results for t = 0.970000 s, Elapsed simulation time: 7.150221 s
# Saving results for t = 0.980000 s, Elapsed simulation time: 7.224453 s
# Saving results for t = 0.990000 s, Elapsed simulation time: 7.299164 s
# Saving results for t = 1.000000 s, Elapsed simulation time: 7.373765 s
# Saving results for t = 1.010000 s, Elapsed simulation time: 7.447276 s
# Saving results for t = 1.020000 s, Elapsed simulation time: 7.520112 s
# Saving results for t = 1.030000 s, Elapsed simulation time: 7.593512 s
# Saving results for t = 1.040000 s, Elapsed simulation time: 7.667117 s
# Saving results for t = 1.050000 s, Elapsed simulation time: 7.741329 s
# Saving results for t = 1.060000 s, Elapsed simulation time: 7.815194 s
# Saving results for t = 1.070000 s, Elapsed simulation time: 7.889078 s
# Saving results for t = 1.080000 s, Elapsed simulation time: 7.965528 s
# Saving results for t = 1.090000 s, Elapsed simulation time: 8.038458 s
# Saving results for t = 1.100000 s, Elapsed simulation time: 8.111605 s
# Saving results for t = 1.110000 s, Elapsed simulation time: 8.184655 s
# Saving results for t = 1.120000 s, Elapsed simulation time: 8.259095 s
# Saving results for t = 1.130000 s, Elapsed simulation time: 8.332817 s
# Saving results for t = 1.140000 s, Elapsed simulation time: 8.406848 s
# Saving results for t = 1.150000 s, Elapsed simulation time: 8.480541 s
# Saving results for t = 1.160000 s, Elapsed simulation time: 8.554456 s
# Saving results for t = 1.170000 s, Elapsed simulation time: 8.627630 s
# Saving results for t = 1.180000 s, Elapsed simulation time: 8.701401 s
# Saving results for t = 1.190000 s, Elapsed simulation time: 8.774273 s
# Saving results for t = 1.200000 s, Elapsed simulation time: 8.847233 s
# Saving results for t = 1.210000 s, Elapsed simulation time: 8.920982 s
# Saving results for t = 1.220000 s, Elapsed simulation time: 8.995805 s
# Saving results for t = 1.230000 s, Elapsed simulation time: 9.069417 s
# Saving results for t = 1.240000 s, Elapsed simulation time: 9.143450 s
# Saving results for t = 1.250000 s, Elapsed simulation time: 9.217330 s
# Saving results for t = 1.260000 s, Elapsed simulation time: 9.290170 s
# Saving results for t = 1.270000 s, Elapsed simulation time: 9.363140 s
# Saving results for t = 1.280000 s, Elapsed simulation time: 9.436906 s
# Saving results for t = 1.290000 s, Elapsed simulation time: 9.510242 s
# Saving results for t = 1.300000 s, Elapsed simulation time: 9.583021 s
# Saving results for t = 1.310000 s, Elapsed simulation time: 9.656850 s
# Saving results for t = 1.320000 s, Elapsed simulation time: 9.730551 s
# Saving results for t = 1.330000 s, Elapsed simulation time: 9.804748 s
# Saving results for t = 1.340000 s, Elapsed simulation time: 9.878431 s
# Saving results for t = 1.350000 s, Elapsed simulation time: 9.952420 s
# Saving results for t = 1.360000 s, Elapsed simulation time: 10.025614 s
# Saving results for t = 1.370000 s, Elapsed simulation time: 10.098609 s
# Saving results for t = 1.380000 s, Elapsed simulation time: 10.172236 s
# Saving results for t = 1.390000 s, Elapsed simulation time: 10.246706 s
# Saving results for t = 1.400000 s, Elapsed simulation time: 10.319517 s
# Saving results for t = 1.410000 s, Elapsed simulation time: 10.392453 s
# Saving results for t = 1.420000 s, Elapsed simulation time: 10.465701 s
# Saving results for t = 1.430000 s, Elapsed simulation time: 10.539560 s
# Saving results for t = 1.440000 s, Elapsed simulation time: 10.612466 s
# Saving results for t = 1.450000 s, Elapsed simulation time: 10.685687 s
# Saving results for t = 1.460000 s, Elapsed simulation time: 10.759869 s
# Saving results for t = 1.470000 s, Elapsed simulation time: 10.833298 s
# Saving results for t = 17.070000 s, Elapsed simulation time: 125.922638 s
# Saving results for t = 17.080000 s, Elapsed simulation time: 125.997341 s
# Saving results for t = 17.090000 s, Elapsed simulation time: 126.071030 s
# Saving results for t = 17.100000 s, Elapsed simulation time: 126.145355 s
# Saving results for t = 17.110000 s, Elapsed simulation time: 126.218850 s
# Saving results for t = 17.120000 s, Elapsed simulation time: 126.292352 s
# Saving results for t = 17.130000 s, Elapsed simulation time: 126.365251 s
# Saving results for t = 17.140000 s, Elapsed simulation time: 126.438232 s
# Saving results for t = 17.150000 s, Elapsed simulation time: 126.511836 s
# Saving results for t = 17.160000 s, Elapsed simulation time: 126.584856 s
# Saving results for t = 17.170000 s, Elapsed simulation time: 126.658159 s
# Saving results for t = 17.180000 s, Elapsed simulation time: 126.730978 s
# Saving results for t = 17.190000 s, Elapsed simulation time: 126.805783 s
# Saving results for t = 17.200000 s, Elapsed simulation time: 126.878922 s
# Saving results for t = 17.210000 s, Elapsed simulation time: 126.952338 s
# Saving results for t = 17.220000 s, Elapsed simulation time: 127.025987 s
# Saving results for t = 17.230000 s, Elapsed simulation time: 127.100073 s
# Saving results for t = 17.240000 s, Elapsed simulation time: 127.173801 s
# Saving results for t = 17.250000 s, Elapsed simulation time: 127.247982 s
# Saving results for t = 17.260000 s, Elapsed simulation time: 127.321438 s
# Saving results for t = 17.270000 s, Elapsed simulation time: 127.394550 s
# Saving results for t = 17.280000 s, Elapsed simulation time: 127.467324 s
# Saving results for t = 17.290000 s, Elapsed simulation time: 127.540790 s
# Saving results for t = 17.300000 s, Elapsed simulation time: 127.614525 s
# Saving results for t = 17.310000 s, Elapsed simulation time: 127.688351 s
# Saving results for t = 17.320000 s, Elapsed simulation time: 127.762322 s
# Saving results for t = 17.330000 s, Elapsed simulation time: 127.836127 s
# Saving results for t = 17.340000 s, Elapsed simulation time: 127.909184 s
# Saving results for t = 17.350000 s, Elapsed simulation time: 127.982747 s
# Saving results for t = 17.360000 s, Elapsed simulation time: 128.059012 s
# Saving results for t = 17.370000 s, Elapsed simulation time: 128.132289 s
# Saving results for t = 17.380000 s, Elapsed simulation time: 128.205168 s
# Saving results for t = 17.390000 s, Elapsed simulation time: 128.278007 s
# Saving results for t = 17.400000 s, Elapsed simulation time: 128.352464 s
# Saving results for t = 17.410000 s, Elapsed simulation time: 128.425940 s
# Saving results for t = 17.420000 s, Elapsed simulation time: 128.498739 s
# Saving results for t = 17.430000 s, Elapsed simulation time: 128.571450 s
# Saving results for t = 17.440000 s, Elapsed simulation time: 128.644693 s
# Saving results for t = 17.450000 s, Elapsed simulation time: 128.718429 s
# Saving results for t = 17.460000 s, Elapsed simulation time: 128.792504 s
# Saving results for t = 17.470000 s, Elapsed simulation time: 128.866936 s
# Saving results for t = 17.480000 s, Elapsed simulation time: 128.941902 s
# Saving results for t = 17.490000 s, Elapsed simulation time: 129.017002 s
# Saving results for t = 17.500000 s, Elapsed simulation time: 129.089791 s
# Saving results for t = 17.510000 s, Elapsed simulation time: 129.162675 s
# Saving results for t = 17.520000 s, Elapsed simulation time: 129.236040 s
# Saving results for t = 17.530000 s, Elapsed simulation time: 129.310325 s
# Saving results for t = 17.540000 s, Elapsed simulation time: 129.383831 s
# Saving results for t = 17.550000 s, Elapsed simulation time: 129.458052 s
# Saving results for t = 17.560000 s, Elapsed simulation time: 129.531873 s
# Saving results for t = 17.570000 s, Elapsed simulation time: 129.605381 s
# Saving results for t = 17.580000 s, Elapsed simulation time: 129.678276 s
# Saving results for t = 17.590000 s, Elapsed simulation time: 129.751394 s
# Saving results for t = 17.600000 s, Elapsed simulation time: 129.825248 s
# Saving results for t = 17.610000 s, Elapsed simulation time: 129.898911 s
# Saving results for t = 17.620000 s, Elapsed simulation time: 129.972499 s
# Saving results for t = 17.630000 s, Elapsed simulation time: 130.045987 s
# Saving results for t = 17.640000 s, Elapsed simulation time: 130.121026 s
# Saving results for t = 17.650000 s, Elapsed simulation time: 130.194855 s
# Saving results for t = 17.660000 s, Elapsed simulation time: 130.267568 s
# Saving results for t = 17.670000 s, Elapsed simulation time: 130.340441 s
# Saving results for t = 17.680000 s, Elapsed simulation time: 130.413407 s
# FP velocity 1.528e+00 (mm/s)

# %%
# Sam's interactive data
# results_data extrapolation
results_data = loadResults(save_dir, "data_DCPD")  # load from .mat file

T=results_data['T_data']
T1=T[300,:]
x=results_data['x_data'][300,:]

# define normalized curve
theta=(T1-np.min(T1))/(np.max(T1)-np.min(T1))

# interpolation function for x_d
alpha_fun = itp.interp1d(theta, x, kind='linear', assume_sorted=False, bounds_error=False, fill_value='extrapolate')
x_d = alpha_fun(0.5)
x_gs = alpha_fun(0.02)
print(x_gs)

# magic shift to get gap at 0, redef x_d
#x-=x_gs
#alpha_fun = itp.interp1d(theta, x, kind='linear', assume_sorted=False, bounds_error=False, fill_value='extrapolate')
#x_d = alpha_fun(0.5)
#x_gs = alpha_fun(0.0001)

# constants!
a=kr/(rhor*Cpr)
# Out:
# 0.004825306665966296

# %%
# plot initial curve
plt.plot(x,T1)
plt.xlabel("x")
plt.ylabel(r'$T~^oK$')
plt.title("DCPD Heat Curve Data")
# Out:
# Text(0.5, 1.0, 'DCPD Heat Curve Data')

# %%
# plot normalized curve
plt.plot(x,theta)
plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Normalized Heat Curve")
# Out:
# Text(0.5, 1.0, 'Normalized Heat Curve')

# %%
# retune this?
k=10000
thetaf = (1/2)*(1+np.tanh(k*(x_d-x)))

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

plt.plot(x,theta,label=r"DCPD Heat Curve ${\Theta}$")
plt.plot(x,thetaf,label="Heaviside Approximation ${\Theta}_{f(x)}$")
plt.xlabel("x (m)")
plt.xlim(.003,0.007)
plt.ylabel(r"${\Theta}$")
plt.title(r"Normalized Approximation Function ${\Theta}_{f(x)}$")
plt.legend()

# %%
# define constants / limits
n=25
sum = 0
An = []

# functions as lambdas for scipy to play nice
fx = lambda x:((1/2)*(1+np.tanh(k*(x_d-x))))
fcos = lambda x:((1/2)*(1+np.tanh(k*(x_d-x))))*np.cos((i*np.pi*x)/L)

for i in range(n):
    if i == 0.0:
        an=(1/(L)*quad(fx,0.0,2*L)[0])
        An.append(an)
    else:
        an=(2/L)*quad(fcos,0.0,2*L)[0]
        An.append(an)
for i in range(n):
    if i == 0.0:
        sum+=An[i]
    else:
        sum+=An[i]*np.cos((i*x*np.pi)/L)

plt.plot(x,sum,'b',label="n=25")

# reset constants / limits
# retune this?
n = 250
sum = 0
An = []

for i in range(n):
    if i == 0.0:
        an=(1/(L)*quad(fx,0.0,2*L)[0])
        An.append(an)
    else:
        an=(2/L)*quad(fcos,0.0,2*L)[0]
        An.append(an)
for i in range(n):
    if i == 0.0:
        sum+=An[i]
    else:
        sum+=An[i]*np.cos((i*x*np.pi)/L)

        
plt.plot(x,sum,'g',label="n=250")
plt.plot(x,thetaf,'r--',label=r"$\theta _{f(x)}$")

plt.xlim(0,0.010)
plt.xlabel("x (m)")
plt.ylabel(r"${\Theta}$")
plt.title(r"Fourier Series Approximation of ${\Theta}_{f(x)}$")
plt.legend()

# %%
Tn=0
t=0

plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

for t in range(0,11,5):
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
    plt.plot(x,Tn,label=f"t={t}s")
    
t=25
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")
    
t=100
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")

t=200
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")


plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Time Evolution of Solution")

plt.legend()

# %%
def find_nearest(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return idx
    else:
        return idx

find_first = lambda a, val, tol: next(i for i, _ in enumerate(a) if np.isclose(_, val, tol))

import glob
import sys
Tn=0
t=0
n=250

h = 0
a=kr/(rhor*Cpr)
b=h/(rhor*Cpr)

lmbda = lambda i, L : (((i*np.pi)/L)**2)
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))

# plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

times = [0,5,7.5,10,12.5,15]
#times = [0,5,10,20,30]
for t in times:
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda(i,L)*a*t)
    Tn = (Tn*(np.max(T1)-(np.min(T1))))+(np.min(T1)-273)
    plt.plot(x-x_d,Tn,label=f"Analytical: {t}s")
    tar = find_nearest(Tn,64.28926800340241)
    np.set_printoptions(threshold=6)
    print(tar)
    print(tar-5)
    print(tar+5)
    print(Tn[tar-5:tar+5])
    print(Tn)
    
times = [0,500,750,1000,1250,1500]
for file in glob.iglob(save_dir + "/*.mat"):
    name = file[9:-4]
    gaplen,hval = file[14:-4].split("_")
    gaplen = str(float(gaplen) / 1e3)
    if gaplen == "0.001" and hval == "0":
        break
results_data = loadResults(save_dir, name)
x = results_data['x_data'][0,:]
zeroidx = find_nearest(x,0.0)
targetidx = find_nearest(x,0.001)
alpha=results_data['alpha_data'][:,zeroidx]
T = results_data['T_data'][:,zeroidx] - 273
theta = (T-np.min(T))/(np.max(T)-np.min(T))
t = results_data['t_data'][:,zeroidx]
tidx = find_nearest(theta, 0.5)
print(T[tidx])
t_gs=t[int(tidx)]
for time in times:
    T = results_data['T_data'][int(t_gs*100)+time,:] - 273
    print(T[targetidx])
    x = results_data['x_data'][int(t_gs*100)+time,:]
    plt.plot(x,T,'--',label=f"FEM: {time/100}s")
plt.legend()


plt.xlim(-0.001,0.002)
plt.xlabel("x (m)")
plt.ylabel(r'$T~^oC$')
plt.title("Temperature Evolution of Solution at Gap")

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
# Out:
# 516
# 511
# 521
# [ 27.28158614  31.28981784  37.60182592 ... 109.9046535  129.92523525
#  149.85744108]
# [20.18635585 20.20215907 20.20345902 ... 20.19977575 20.18618062
#  20.13470421]
# 479
# 474
# 484
# [59.13115294 60.29857402 61.48744718 ... 67.74913151 69.06375874
#  70.39866365]
# [20.14771853 20.14771853 20.14771853 ... 20.14771853 20.14771853
#  20.14771853]
# 470
# 465
# 475
# [60.10148501 61.0690477  62.05090742 ... 67.17207892 68.2380456
#  69.31766671]
# [20.14771853 20.14771853 20.14771853 ... 20.14771853 20.14771853
#  20.14771853]
# 462
# 457
# 467
# [60.3496216  61.19052613 62.0421631  ... 66.45966926 67.37463085
#  68.29992077]
# [20.14771853 20.14771853 20.14771853 ... 20.14771853 20.14771853
#  20.14771853]
# 455
# 450
# 460
# [60.55881876 61.31316725 62.07610441 ... 66.01842886 66.83213781
#  67.65415164]
# [20.14771853 20.14771853 20.14771853 ... 20.14771853 20.14771853
#  20.14771853]
# 449
# 444
# 454
# [60.94125954 61.6337291  62.3333495  ... 65.93778197 66.67971655
#  67.42858389]
# [20.14771863 20.14771864 20.14771865 ... 20.14771853 20.14771853
#  20.14771853]
# 109.83899975160858
# 20.155672579909492
# 53.69198795185895
# 64.28926800340241
# 71.75429693830762
# 78.07072734565747
# 87.26195214864407

# %%
def find_nearest(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return idx
    else:
        return idx

find_first = lambda a, val, tol: next(i for i, _ in enumerate(a) if np.isclose(_, val, tol))

import glob
import sys
Tn=0
t=0
n=250
gap = 0.001
h = 0
tdiff = 0.15267863661495
a=kr/(rhor*Cpr)
b=h/(rhor*Cpr)

lmbda = lambda i, L : (((i*np.pi)/L)**2)
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))

A = 8.55e15
E = 1.1075e5
R = 8.3144621
n_g = 1.720
m_g = 0.770
c_g = 14.480
a_cg = 0.410
t_range = np.linspace(20,100,80)
alpha_o = 0.01
da_dt = []

g_a = lambda alpha : ((1-alpha)**n_g)*(alpha**m)*(1/(1+np.exp(c_g*(alpha-a_cg))))
f_a = lambda alpha : 1/(A*np.exp(-E/(R*((Hr/Cpr)*(alpha - alpha_o)+t_o)))*g_a(alpha))

# plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

# Analytical Temp vs X plot
"""
times = [0,5,7.5,10,12.5,15]
#times = [0,5,10,20,30]
for t in times:
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda(i,L)*a*t)
#        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    plt.plot(x-x_d,(Tn*(np.max(T1)-(np.min(T1)))+(np.min(T1)-273)),label=f"Analytical: {t}s")
""" 

# Analytical Temp vs Time plot
"""
tspace = np.linspace(0,40,1550)
Tn = 0
i = 0
for i in range(n):
    Tn += An[i]*np.cos((i*(x_d+gap)*np.pi)/L)*np.exp(-lmbda(i,L)*a*tspace)
plt.plot(tspace,(Tn*(np.max(T1)-(np.min(T1)))+(np.min(T1)-273)),label=f"Analytical: {t}s")
"""

# Analytical Alpha vs Time plot

i_n = 0
alphan = []
alpha_val = 0
t = np.linspace(0,40,10000)
dt = t[2]-t[1]

for i in t[:9999]:
    i_n += 1
    if i == 0:
        alphan.append(alpha0)
        pass
    alpha_val = alphan[i_n-1] + A*np.exp(-E/(R*(fouriertemp_k(x_d+gap,i,0)-tdiff))) * g_a(alphan[i_n-1]) * dt
    alphan.append(alpha_val)
plt.plot(t,alphan,label="Analytical")


# Numerical Temp vs X plot
"""
times = [0,500,750,1000,1250,1500]
for file in glob.iglob(save_dir + "/*.mat"):
    name = file[9:-4]
    gaplen,hval = file[14:-4].split("_")
    gaplen = str(float(gaplen) / 1e3)
    if gaplen == "0.001" and hval == "0":
        break
results_data = loadResults(save_dir, name)
x = results_data['x_data'][0,:]
zeroidx = find_nearest(x,0.0)
alpha=results_data['alpha_data'][:,zeroidx]
T = results_data['T_data'][:,zeroidx] - 273
theta = (T-np.min(T))/(np.max(T)-np.min(T))
t = results_data['t_data'][:,zeroidx]
tidx = find_nearest(theta, 0.5)
print(T[tidx])
t_gs=t[int(tidx)]
for time in times:
    T = results_data['T_data'][int(t_gs*100)+time,:] - 273
    x = results_data['x_data'][int(t_gs*100)+time,:]
    plt.plot(x,T,'--',label=f"FEM: {time/100}s")
plt.legend()


plt.xlim(-0.001,0.002)
plt.xlabel("x (m)")
plt.ylabel(r'$T~^oC$')
plt.title("Temperature Evolution of Solution through Gap")
"""

# Numerical Temp vs Time plot
"""
for file in glob.iglob(save_dir + "/*.mat"):
    name = file[9:-4]
    if name == "data_DCPD":
        continue
    gaplen,hval = file[14:-4].split("_")
    gaplen = str(float(gaplen) / 1e3)
    if gaplen == "0.001" and hval == "0":
        break
results_data = loadResults(save_dir, name)
x = results_data['x_data'][0,:]
idx = find_nearest(x,float(gaplen))
zeroidx = find_nearest(x,0.0)
T=results_data['T_data'][:,zeroidx] - 273
theta = (T-np.min(T))/(np.max(T)-np.min(T))

shift = find_nearest(theta,0.5)

T=results_data['T_data'][:,idx] - 273
theta = (T-np.min(T))/(np.max(T)-np.min(T))
t=results_data['t_data'][:,idx]
targettime = find_nearest(t - t[shift], 5)
print(T[targettime])

plt.plot(t-t[shift],T,'--',label="FEM")
plt.xlim(0,30)
plt.xlabel("t (s)")
plt.ylabel(r'$T~^oC$')
plt.title("Temperature Evolution of Solution at End of Gap")
"""

# Numerical Alpha vs Time plot

for file in glob.iglob(save_dir + "/*.mat"):
    name = file[9:-4]
    if name == "data_DCPD":
        continue
    gaplen,hval = file[14:-4].split("_")
    gaplen = str(float(gaplen) / 1e3)
    if gaplen == "0.001" and hval == "0":
        break
results_data = loadResults(save_dir, name)
x = results_data['x_data'][0,:]
idx = find_nearest(x,float(gaplen))
zeroidx = find_nearest(x,0.0)
T=results_data['T_data'][:,zeroidx] - 273
theta = (T-np.min(T))/(np.max(T)-np.min(T))

shift = find_nearest(theta,0.5)

t=results_data['t_data'][:,idx]
alpha=results_data['alpha_data'][:,idx]

plt.plot(t-t[shift],alpha,'--',label="FEM")
plt.xlim(0,30)
plt.xlabel("t (s)")
plt.ylabel(r'$\alpha$')
plt.title("alpha Evolution of Solution at End of Gap")


plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
# Out:
# 0.6804219640302455

# %%
Tn=0
t=0

lmbda = lambda i, L : (((i*np.pi)/L)**2)
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))

# plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

for t in range(0,21,):
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda(i,L)*a*t)
#        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    plt.plot(x,Tn,label=f"t={t}s")
    



plt.xlabel("x")
plt.ylabel(r"${\Theta}$")

plt.title("Time Evolution of Solution")

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %%
### Matthews Method starts here.

# %%
### THIS IS MY BREAK FOR BP/Ts

# %%
### END BREAK

# %%
A = 8.55e15
E = 1.1075e5
R = 8.3144621
n_g = 1.720
m_g = 0.770
c_g = 14.480
a_cg = 0.410
t_range = np.linspace(20,100,80)
alpha_o = 0.01
da_dt = []

g_a = lambda alpha : ((1-alpha)**n_g)*(alpha**m)*(1/(1+np.exp(c_g*(alpha-a_cg))))
f_a = lambda alpha : 1/(A*np.exp(-E/(R*((Hr/Cpr)*(alpha - alpha_o)+t_o)))*g_a(alpha))
for t_o in range(20+273, 100+273):
    da_dt.append(quad(f_a, alpha_o, 0.5)[0])

T_s = (np.interp(1.55,da_dt[::-1],t_range))
T_s = 100-(T_s-20)

# %%
from fractions import Fraction
gaps = [0.0005, 0.001, 0.002, 0.003, 0.005, 0.01]
t = np.linspace(0,100,100)
Tf = np.min(T1) + (Hr*(1-alpha0)/Cpr)
D = kr/(rhor*Cpr)
vc = (((A*kr*R*(Tf**2))/(rhor*Hr*(1-alpha0)*E)) * np.exp((-E)/(R*Tf)))**0.5
lc = D/(vc)


temp = []
for gap in gaps:
    temp.append(fouriertemp(gap+x_gs, t, 0*kr/(lc**2)))
    plt.plot(t,temp[0],label=f"{gap}m")
#    plt.plot(t,temp[0],label=r"gapsize=$\frac{{1}}{{{}}}$m".format(1/gap))
#    plt.plot(t,temp[0],label=r"$h_l$=" + f"{h/kl:.1f}" + r"$\kappa/L^2$" + r'$\frac{W}{m^3K}$')    
    temp = []
    
plt.xlabel("Time (s)")
plt.ylabel(r'$T~^oC$')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=6)
plt.title(r"Adiabatic Temperature Evolution for Varying Gap Size")
# Out:
# Text(0.5, 1.0, 'Adiabatic Temperature Evolution for Varying Gap Size')

# %%
from tqdm.notebook import tqdm
#gaps = [0.0005, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045, 0.005, 0.0055, 0.006, 0.0065, 0.007, 0.0075, 0.008, 0.0085, 0.009, 0.0095, 0.01]
#hs = [0,0.001*rhor*Cpr,0.002*rhor*Cpr,0.003*rhor*Cpr,0.004*rhor*Cpr,0.005*rhor*Cpr]

g_a = lambda alpha : ((1-alpha)**n_g)*(alpha**m)*(1/(1+np.exp(c_g*(alpha-a_cg))))
gaps = np.linspace(0,0.005,501)
kl = kr/(L**2)
#hs = [0, 1/100, 1/200, 1/300, 1/400, 1/500, 1/1000, 1/5000]
hs = [0, 1/250000, 1/500000, 1/1000000, 1/2000000, 1/3000000, 1/50000000]
timespace = np.linspace(0,260,10000)
dt = timespace[2]-timespace[1]
tdiff = 0.15267863661495
t0s = [0,10,20,30]
alpha0 = 0.01
alphan = []
i_n = 0
t_sl = []
# Tf is working in kelvins
Tf = np.min(T1) + (Hr*(1-alpha0)/Cpr)
D = kr/(rhor*Cpr)
vc = (((A*kr*R*(Tf**2))/(rhor*Hr*(1-alpha0)*E)) * np.exp((-E)/(R*Tf)))**0.5
lc = D/(vc)
print(lc)

data_save = {0:[], 1/250000:[], 1/500000:[], 1/1000000:[], 1/2000000:[], 1/3000000:[], 1/50000000:[]}

tn = 0
# i is always t
for h in hs: 
    for gap in gaps:
        for i in timespace[:9999]:
            # to prevent divide by zero
            if gap == 0:
                hcurr = 0
            else:
                hcurr = (h*kr/(lc**2))
            i_n += 1
            if i == 0:
                alphan.append(alpha0)
                pass
            alpha_val = alphan[i_n-1] + A*np.exp(-E/(R*(fouriertemp_k(x_gs+gap,i,hcurr)-tdiff+tn))) * g_a(alphan[i_n-1]) * dt
            alphan.append(alpha_val)
        t_sl.append(np.interp(0.25,alphan,timespace))
        data_save[h].append([gap, np.interp(0.25,alphan,timespace)])
        alphan = []
        i_n = 0
    #plt.plot(gaps,t_sl,label=r"$h_l$=" + f"{h/kl:.1f}" + r"$\kappa/L^2$" + r'$\frac{W}{m^3K}$')
    if h == 0:
        plt.plot(gaps,t_sl,label="Adiabatic")
    else:
        plt.plot(gaps,t_sl,label=r"$h_l$=" + r"$\frac{{1}}{{{:.1e}}}$".format(int(1/h)) + r"$\kappa/L_c^2$")
    t_sl = []
plt.title("Gap Cross Time for Varying Heat Loss")
plt.xlabel("Gap Size (m)")
plt.ylabel(r'$t_{sl}$ (s)')
plt.ylim(0,250)
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
# Out:
# 5.269650975264228e-06

# %%
# I'll process in this one
import glob
hs = [0, 1/250000, 1/500000, 1/1000000, 1/3000000]

for h in hs:
    x,y = zip(*data_save[h])
    if h == 0:
        plt.plot(x,y,label=f"Analytical Adiabatic")
    else:
        plt.plot(x,y,label=r"Analytical, $h_L$=" + r"$\frac{{1}}{{{:.1e}}}$".format(int(1/h)) + r"$\kappa/L_c^2$")
    
def find_nearest(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return idx
    else:
        return idx

# make a matrix where we can interate h -> gap,time then loop the h's and plot scatters

proc_data = {0:[], 250000:[], 500000:[], 1000000:[], 2000000:[], 3000000:[], 50000000:[]}


for file in glob.iglob(str(save_dir) + "/*.mat"):
    name = file[9:-4]
    gaplen,hval = file[14:-4].split("_")
    if hval == "0":
        results_data = loadResults(save_dir, name)
        gaplen = str(float(gaplen) / 1e3)
        if gaplen == "0.0045":
            continue
        elif float(gaplen) <= 0.005:
            x = results_data['x_data'][0,:]
            idx = find_nearest(x,float(gaplen))
            alpha=results_data['alpha_data'][:,idx-1]
            t=results_data['t_data'][:,idx-1]
            halftime = np.interp(0.25,alpha,t)
            data_point = [float(gaplen), halftime - 9.25]
            proc_data[int(hval)].append(data_point)
    elif 1/float(hval) in hs:
        results_data = loadResults(save_dir, name)
        gaplen = str(float(gaplen) / 1e3)
        if gaplen == "0.0045":
            continue
        if float(gaplen) <= 0.005:
            x = results_data['x_data'][0,:]
            idx = find_nearest(x,float(gaplen))
            alpha=results_data['alpha_data'][:,idx-1]
            t=results_data['t_data'][:,idx-1]
            halftime = np.interp(0.25,alpha,t)
            data_point = [float(gaplen), halftime - 9.25]
            proc_data[int(hval)].append(data_point)


for h in hs:
    if h == 0:
        proc_data[0].sort()
        if not bool(proc_data[0]):
            continue
        x,y = zip(*proc_data[0])
        plt.plot(x,y,label=f"Numerical Adiabatic",linestyle="dashed",marker="o")
    else:
        proc_data[int(1/h)].sort()
        if not bool(proc_data[int(1/h)]):
            continue
        x,y = zip(*proc_data[int(1/h)])
        plt.plot(x,y,label=r"Numerical, $h_l$=" + r"gapsize=$\frac{{1}}{{{}}}$".format(int(1/h)) + r"$\kappa/L_c^2$",linestyle="dashed",marker="o")
plt.title("Gap Cross Time for Varying Heat Loss")
plt.xlabel("Gap Size (m)")
plt.ylabel(r'$t_{sl}$ (s)')
plt.ylim(0,250)
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %%
from fractions import Fraction
import glob

gaps = [0.001]
hs = [0]
t = np.linspace(0,50,1000)
dt = t[2]-t[1]
i_n = 0
t_sl = []

temp = []

Tf = np.min(T1) + (Hr*(1-alpha0)/Cpr)
D = kr/(rhor*Cpr)
vc = (((A*kr*R*(Tf**2))/(rhor*Hr*(1-alpha0)*E)) * np.exp((-E)/(R*Tf)))**0.5
lc = D/(vc**2)

def find_nearest(array,value):
    idx = np.searchsorted(array, value, side="left")
    if idx > 0 and (idx == len(array) or math.fabs(value - array[idx-1]) < math.fabs(value - array[idx])):
        return idx
    else:
        return idx
    
for h in hs:
    for gap in gaps:
        temp.append(fouriertemp(gap+x_gs, t, h*kr/(lc**2)))
        plt.plot(t,temp[0],label="Analytical")

alphan = []
for h in hs:
    for gap in gaps:
        for i in t[:999]:
            hcurr = 0
            i_n += 1
            if i == 0:
                alphan.append(alpha0)
                pass
            alpha_val = alphan[i_n-1] + A*np.exp(-E/(R*(fouriertemp_k(x_gs+gap,i,hcurr)-tdiff))) * g_a(alphan[i_n-1]) * dt
            alphan.append(alpha_val)
        i_n = 0

templist = []
for element in alphan:
    templist.append(element*200)
#plt.plot(t,alphan,label="analytical")      
alphan = []

for file in glob.iglob(save_dir + "/*.mat"):
    name = file[9:-4]
    if name == "data_DCPD":
        continue
    gaplen,hval = file[14:-4].split("_")
    gaplen = str(float(gaplen) / 1e3)
    if gaplen == "0.001" and hval == "0":
        break
print(name)
results_data = loadResults(save_dir, name)
x = results_data['x_data'][0,:]
idx = find_nearest(x,float(gaplen))
alph=results_data['alpha_data'][:,idx]
T=results_data['T_data'][:,idx] - 273
t=results_data['t_data'][:,idx]
plt.plot(t-9.83,T,label="Numerical")
print(idx)
print(alph)
#plt.plot(t-9.25,alph,label="Numerical")

        
plt.xlabel("Time (s)")
plt.ylabel(r'$T~^oC$')
plt.legend()
plt.title(r"Temperature Evolution for Adiabatic Case, Gap = 0.001m")
plt.xlim(0)
# Out:
# data_1.0_0
# 775
# [0.01       0.01000004 0.01000009 ... 0.96292817 0.96297212 0.96301599]
# (0.0, 52.9915)

# %%
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))
#hs = [0,0.001*rhor*Cpr,0.002*rhor*Cpr,0.003*rhor*Cpr,0.004*rhor*Cpr]
#gaps = np.linspace(0,.002,100)
#t = np.linspace(0,100,100)
#n = 250

def fouriertemp(x,t,h):
    theta_xth = 0
    b = h/(rhor*Cpr)
    for i in range(n):
        theta_xth += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    T_xth = theta_xth * (np.max(T1)-np.min(T1)) + np.min(T1) - 273
    return T_xth

def fouriertemp_k(x,t,h):
    theta_xth = 0
    b = h/(rhor*Cpr)
    for i in range(n):
        theta_xth += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    T_xth = theta_xth * (np.max(T1)-np.min(T1)) + np.min(T1)
    return T_xth

#t_gs1 = []
#for h in hs:
#    for gap in gaps:
#        x_ge = x_gs + gap
#        t_gs1.append(np.interp(T_s,fouriertemp(x_ge,t,h),t))
#        #plt.plot(t,fouriertemp(x_ge,t,0))
#    plt.plot(gaps*500, t_gs1,label=f"h={h}")
#    t_gs1 = []
#plt.xlabel("gap length")
#plt.ylabel("seconds to 82C")
#plt.legend()

# %%
hs = [0,0.001*rhor*Cpr,0.002*rhor*Cpr,0.003*rhor*Cpr,0.004*rhor*Cpr]
gaps = np.linspace(0,.001,100)
t = np.linspace(0,60,100)
n = 250
t_gs = 100

g_ainv = lambda alpha : 1/((1-alpha)**n_g)*(alpha**m)*(1/(1+np.exp(c_g*(alpha-a_cg))))

def solve(x,t,h):
    def ftemp(t):
        return A*np.exp(-E/(R*fouriertemp_k(x,t,h)))
    def rhfunc(t_gs):
        rhs,__= quad(ftemp,0,t_gs)
        return rhs-lhs
    lhs,__ = quad(g_ainv,alpha_o,0.5)
    t_gs = optimize.newton(rhfunc,5,tol=1e-20,maxiter=10000)
    return t_gs
    

for h in hs:
    for gap in gaps:
        x_ge = x_gs + gap + 0.0001
        print("L: " + str(L))
        print("x_gs: " + str(x_gs))
        print("x_ge: " + str(x_ge))
        result = solve(x_ge,t,h)
        print("output of somefun integral: " + str(result))
    #plt.plot(gaps,t_gs,label=f"h={h}")
#plt.xlabel("gap length")
#plt.ylabel("seconds to 82C")
#plt.legend()
# Out:
# L: 0.01
# x_gs: 0.005121686223999055
# x_ge: 0.005221686223999055
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [315], in <cell line: 20>()
#      24         print("x_gs: " + str(x_gs))
#      25         print("x_ge: " + str(x_ge))
# ---> 26         result = solve(x_ge,t,h)
#      27         print("output of somefun integral: " + str(result))
#      28     #plt.plot(gaps,t_gs,label=f"h={h}")
#      29 #plt.xlabel("gap length")
#      30 #plt.ylabel("seconds to 82C")
#      31 #plt.legend()
#
# Input In [315], in solve(x, t, h)
#      14     return rhs-lhs
#      15 lhs,__ = quad(g_ainv,alpha_o,0.5)
# ---> 16 t_gs = optimize.newton(rhfunc,5,tol=1e-20,maxiter=10000)
#      17 return t_gs
#
# File ~/mambaforge3/envs/fenics/lib/python3.8/site-packages/scipy/optimize/_zeros_py.py:348, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     344     if disp:
#     345         msg += (
#     346             " Failed to converge after %d iterations, value is %s."
#     347             % (itr + 1, p1))
# --> 348         raise RuntimeError(msg)
#     349     warnings.warn(msg, RuntimeWarning)
#     350 p = (p1 + p0) / 2.0
#
# RuntimeError: Tolerance of 0.0005999999999994898 reached. Failed to converge after 1 iterations, value is 5.0005999999999995.
