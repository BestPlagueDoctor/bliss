# %%
import os
import time
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.animation as animation
import scipy.io as scio

from dolfin import *
from fenics import *
import warnings

# %%
# Geubelle research group
# Authors:  Qibang Liu (qibang@illinois.edu)
#           Michael Zakoworotny (mjz7@illinois.edu)
#           Philippe Geubelle (geubelle@illinois.edu)
#           Aditya Kumar (aditya.kumar@ce.gatech.edu)
#
# An example of running the FP solver for DCPD

import os
from solver_FP import FP_solver
from kinetics_library import Prout_Tompkins_Diffusion
from postProcess_FP import Post_process, saveResults, loadResults


# Sam's imports
from scipy import interpolate as itp
from scipy.integrate import quad


# Switch to current directory
try:
    os.chdir(os.path.dirname(__file__))
except:
    print("Cannot switch directories")

# Thermo-chemical properties
kr = 0.15      # thermal conductivity, W/m-K
rhor = 980.0    # density, kg/m^3
Cpr = 1600.0    # specific heat, J/kg-K

# Nature values
Hr = 350000    # enthalpy, J/kg
A_ = 8.55e15    # pre-exponential constant, 1/s
Er = 110750.0   # activation energy J/mol
n = 1.72        # cure kinetics parameter
m = 0.77        # cure kinetics parameter
Ca = 14.48      # cure kinetics parameter
alpha_c = 0.41  # cure kinetics parameter

# Create an object for the cure kinetics model
ptd_model = Prout_Tompkins_Diffusion(n, m, Ca, alpha_c)

# Initial conditions for temperature and degree of cure
T0 = 20         # deg C
alpha0 = 0.01

# Length of domain
L = 0.03

# Initialize the solver with the parameters
solver = FP_solver(kr, rhor, Cpr, Hr, A_, Er,
                   ptd_model, T0, alpha0, L=L, h_x=2e-5)

# Run the solver until 10 s
t_end = 10
results_data = solver.solve(
    t_end, outputFreq_t=10, outputFreq_x=1)

# %%
# Post-process - generate report, compute the front speed, and save an animation of the temperature and alpha fronts
save_dir = "out_DCPD"  # path to save the result files.
pts_ = [2e-3, 5e-3]  # Get evolution of alpha and T at this points
# create post process object
post_pro = Post_process(results_data, solver, pts=pts_,
                        save_dir=save_dir, save_suffix="DCPD", anim_frames=100, fid=0)
post_pro.generateReport()  # generate report


# %%
# Pack the results for future use
saveResults(results_data, save_dir, "data_DCPD")  # save to .mat file
loadedResults = loadResults(save_dir, "data_DCPD")  # load from .mat file
# Out:
# Cannot switch directories
# Saving results for t = 0.010000 s, Elapsed simulation time: 0.042187 s
# Saving results for t = 0.020000 s, Elapsed simulation time: 0.084652 s
# Saving results for t = 0.030000 s, Elapsed simulation time: 0.127197 s
# Saving results for t = 0.040000 s, Elapsed simulation time: 0.169504 s
# Saving results for t = 0.050000 s, Elapsed simulation time: 0.213126 s
# Saving results for t = 0.060000 s, Elapsed simulation time: 0.257424 s
# Saving results for t = 0.070000 s, Elapsed simulation time: 0.301751 s
# Saving results for t = 0.080000 s, Elapsed simulation time: 0.344613 s
# Saving results for t = 0.090000 s, Elapsed simulation time: 0.387163 s
# Saving results for t = 0.100000 s, Elapsed simulation time: 0.430423 s
# Saving results for t = 0.110000 s, Elapsed simulation time: 0.474528 s
# Saving results for t = 0.120000 s, Elapsed simulation time: 0.517930 s
# Saving results for t = 0.130000 s, Elapsed simulation time: 0.562431 s
# Saving results for t = 0.140000 s, Elapsed simulation time: 0.605771 s
# Saving results for t = 0.150000 s, Elapsed simulation time: 0.648407 s
# Saving results for t = 0.160000 s, Elapsed simulation time: 0.690996 s
# Saving results for t = 0.170000 s, Elapsed simulation time: 0.733513 s
# Saving results for t = 0.180000 s, Elapsed simulation time: 0.776885 s
# Saving results for t = 0.190000 s, Elapsed simulation time: 0.820994 s
# Saving results for t = 0.200000 s, Elapsed simulation time: 0.865258 s
# Saving results for t = 0.210000 s, Elapsed simulation time: 0.909359 s
# Saving results for t = 0.220000 s, Elapsed simulation time: 0.953501 s
# Saving results for t = 0.230000 s, Elapsed simulation time: 0.997822 s
# Saving results for t = 0.240000 s, Elapsed simulation time: 1.041434 s
# Saving results for t = 0.250000 s, Elapsed simulation time: 1.084157 s
# Saving results for t = 0.260000 s, Elapsed simulation time: 1.126698 s
# Saving results for t = 0.270000 s, Elapsed simulation time: 1.169208 s
# Saving results for t = 0.280000 s, Elapsed simulation time: 1.212149 s
# Saving results for t = 0.290000 s, Elapsed simulation time: 1.256510 s
# Saving results for t = 0.300000 s, Elapsed simulation time: 1.300701 s
# Saving results for t = 0.310000 s, Elapsed simulation time: 1.344824 s
# Saving results for t = 0.320000 s, Elapsed simulation time: 1.388988 s
# Saving results for t = 0.330000 s, Elapsed simulation time: 1.433450 s
# Saving results for t = 0.340000 s, Elapsed simulation time: 1.476377 s
# Saving results for t = 0.350000 s, Elapsed simulation time: 1.518939 s
# Saving results for t = 0.360000 s, Elapsed simulation time: 1.561460 s
# Saving results for t = 0.370000 s, Elapsed simulation time: 1.603997 s
# Saving results for t = 0.380000 s, Elapsed simulation time: 1.646861 s
# Saving results for t = 0.390000 s, Elapsed simulation time: 1.691176 s
# Saving results for t = 0.400000 s, Elapsed simulation time: 1.735538 s
# Saving results for t = 0.410000 s, Elapsed simulation time: 1.778633 s
# Saving results for t = 0.420000 s, Elapsed simulation time: 1.821123 s
# Saving results for t = 0.430000 s, Elapsed simulation time: 1.863655 s
# Saving results for t = 0.440000 s, Elapsed simulation time: 1.906206 s
# Saving results for t = 0.450000 s, Elapsed simulation time: 1.949089 s
# Saving results for t = 0.460000 s, Elapsed simulation time: 1.993145 s
# Saving results for t = 0.470000 s, Elapsed simulation time: 2.037557 s
# Saving results for t = 0.480000 s, Elapsed simulation time: 2.081984 s
# Saving results for t = 0.490000 s, Elapsed simulation time: 2.126365 s
# Saving results for t = 0.500000 s, Elapsed simulation time: 2.170570 s
# Saving results for t = 0.510000 s, Elapsed simulation time: 2.214677 s
# Saving results for t = 0.520000 s, Elapsed simulation time: 2.258772 s
# Saving results for t = 0.530000 s, Elapsed simulation time: 2.301662 s
# Saving results for t = 0.540000 s, Elapsed simulation time: 2.344235 s
# Saving results for t = 0.550000 s, Elapsed simulation time: 2.386757 s
# Saving results for t = 0.560000 s, Elapsed simulation time: 2.429311 s
# Saving results for t = 0.570000 s, Elapsed simulation time: 2.472204 s
# Saving results for t = 0.580000 s, Elapsed simulation time: 2.516473 s
# Saving results for t = 0.590000 s, Elapsed simulation time: 2.560641 s
# Saving results for t = 0.600000 s, Elapsed simulation time: 2.604851 s
# Saving results for t = 0.610000 s, Elapsed simulation time: 2.648623 s
# Saving results for t = 0.620000 s, Elapsed simulation time: 2.691232 s
# Saving results for t = 0.630000 s, Elapsed simulation time: 2.733870 s
# Saving results for t = 0.640000 s, Elapsed simulation time: 2.776472 s
# Saving results for t = 0.650000 s, Elapsed simulation time: 2.818960 s
# Saving results for t = 0.660000 s, Elapsed simulation time: 2.862633 s
# Saving results for t = 0.670000 s, Elapsed simulation time: 2.906802 s
# Saving results for t = 0.680000 s, Elapsed simulation time: 2.951017 s
# Saving results for t = 0.690000 s, Elapsed simulation time: 2.995171 s
# Saving results for t = 0.700000 s, Elapsed simulation time: 3.039466 s
# Saving results for t = 0.710000 s, Elapsed simulation time: 3.083494 s
# Saving results for t = 0.720000 s, Elapsed simulation time: 3.127942 s
# Saving results for t = 0.730000 s, Elapsed simulation time: 3.172168 s
# Saving results for t = 0.740000 s, Elapsed simulation time: 3.214721 s
# Saving results for t = 0.750000 s, Elapsed simulation time: 3.257344 s
# Saving results for t = 0.760000 s, Elapsed simulation time: 3.299880 s
# Saving results for t = 0.770000 s, Elapsed simulation time: 3.342862 s
# Saving results for t = 0.780000 s, Elapsed simulation time: 3.387250 s
# Saving results for t = 0.790000 s, Elapsed simulation time: 3.431644 s
# Saving results for t = 0.800000 s, Elapsed simulation time: 3.477208 s
# Saving results for t = 0.810000 s, Elapsed simulation time: 3.520235 s
# Saving results for t = 0.820000 s, Elapsed simulation time: 3.562837 s
# Saving results for t = 0.830000 s, Elapsed simulation time: 3.605591 s
# Saving results for t = 0.840000 s, Elapsed simulation time: 3.648152 s
# Saving results for t = 0.850000 s, Elapsed simulation time: 3.691103 s
# Saving results for t = 0.860000 s, Elapsed simulation time: 3.735540 s
# Saving results for t = 0.870000 s, Elapsed simulation time: 3.779809 s
# Saving results for t = 0.880000 s, Elapsed simulation time: 3.823937 s
# Saving results for t = 0.890000 s, Elapsed simulation time: 3.868320 s
# Saving results for t = 0.900000 s, Elapsed simulation time: 3.911339 s
# Saving results for t = 0.910000 s, Elapsed simulation time: 3.953915 s
# Saving results for t = 0.920000 s, Elapsed simulation time: 3.996491 s
# Saving results for t = 0.930000 s, Elapsed simulation time: 4.039015 s
# Saving results for t = 0.940000 s, Elapsed simulation time: 4.081838 s
# Saving results for t = 0.950000 s, Elapsed simulation time: 4.126278 s
# Saving results for t = 0.960000 s, Elapsed simulation time: 4.170582 s
# Saving results for t = 0.970000 s, Elapsed simulation time: 4.214826 s
# Saving results for t = 0.980000 s, Elapsed simulation time: 4.258949 s
# Saving results for t = 0.990000 s, Elapsed simulation time: 4.303204 s
# Saving results for t = 1.000000 s, Elapsed simulation time: 4.347287 s
# Saving results for t = 1.010000 s, Elapsed simulation time: 4.389746 s
# Saving results for t = 1.020000 s, Elapsed simulation time: 4.431965 s
# Saving results for t = 1.030000 s, Elapsed simulation time: 4.474118 s
# Saving results for t = 1.040000 s, Elapsed simulation time: 4.516189 s
# Saving results for t = 1.050000 s, Elapsed simulation time: 4.558604 s
# Saving results for t = 1.060000 s, Elapsed simulation time: 4.602670 s
# Saving results for t = 1.070000 s, Elapsed simulation time: 4.646646 s
# Saving results for t = 1.080000 s, Elapsed simulation time: 4.690371 s
# Saving results for t = 1.090000 s, Elapsed simulation time: 4.733930 s
# Saving results for t = 1.100000 s, Elapsed simulation time: 4.776399 s
# Saving results for t = 1.110000 s, Elapsed simulation time: 4.818520 s
# Saving results for t = 1.120000 s, Elapsed simulation time: 4.860653 s
# Saving results for t = 1.130000 s, Elapsed simulation time: 4.902803 s
# Saving results for t = 1.140000 s, Elapsed simulation time: 4.945288 s
# Saving results for t = 1.150000 s, Elapsed simulation time: 4.989312 s
# Saving results for t = 1.160000 s, Elapsed simulation time: 5.032199 s
# Saving results for t = 1.170000 s, Elapsed simulation time: 5.074293 s
# Saving results for t = 1.180000 s, Elapsed simulation time: 5.116430 s
# Saving results for t = 1.190000 s, Elapsed simulation time: 5.158587 s
# Saving results for t = 1.200000 s, Elapsed simulation time: 5.200983 s
# Saving results for t = 1.210000 s, Elapsed simulation time: 5.244656 s
# Saving results for t = 1.220000 s, Elapsed simulation time: 5.288681 s
# Saving results for t = 1.230000 s, Elapsed simulation time: 5.332505 s
# Saving results for t = 1.240000 s, Elapsed simulation time: 5.376231 s
# Saving results for t = 1.250000 s, Elapsed simulation time: 5.419775 s
# Saving results for t = 1.260000 s, Elapsed simulation time: 5.463785 s
# Saving results for t = 1.270000 s, Elapsed simulation time: 5.507526 s
# Saving results for t = 1.280000 s, Elapsed simulation time: 5.551332 s
# Saving results for t = 1.290000 s, Elapsed simulation time: 5.594117 s
# Saving results for t = 1.300000 s, Elapsed simulation time: 5.636383 s
# Saving results for t = 1.310000 s, Elapsed simulation time: 5.678524 s
# Saving results for t = 1.320000 s, Elapsed simulation time: 5.720667 s
# Saving results for t = 1.330000 s, Elapsed simulation time: 5.763147 s
# Saving results for t = 1.340000 s, Elapsed simulation time: 5.806928 s
# Saving results for t = 1.350000 s, Elapsed simulation time: 5.850873 s
# Saving results for t = 1.360000 s, Elapsed simulation time: 5.894624 s
# Saving results for t = 1.370000 s, Elapsed simulation time: 5.938719 s
# Saving results for t = 1.380000 s, Elapsed simulation time: 5.981228 s
# Saving results for t = 1.390000 s, Elapsed simulation time: 6.023431 s
# Saving results for t = 1.400000 s, Elapsed simulation time: 6.065612 s
# Saving results for t = 1.410000 s, Elapsed simulation time: 6.107768 s
# Saving results for t = 1.420000 s, Elapsed simulation time: 6.150438 s
# Saving results for t = 1.430000 s, Elapsed simulation time: 6.194097 s
# Saving results for t = 1.440000 s, Elapsed simulation time: 6.238123 s
# Saving results for t = 1.450000 s, Elapsed simulation time: 6.282047 s
# Saving results for t = 1.460000 s, Elapsed simulation time: 6.325864 s
# Saving results for t = 1.470000 s, Elapsed simulation time: 6.369658 s
# Saving results for t = 1.480000 s, Elapsed simulation time: 6.413707 s
# Saving results for t = 1.490000 s, Elapsed simulation time: 6.458786 s
# Saving results for t = 1.500000 s, Elapsed simulation time: 6.501376 s
# Saving results for t = 1.510000 s, Elapsed simulation time: 6.543477 s
# Saving results for t = 1.520000 s, Elapsed simulation time: 6.585700 s
# Saving results for t = 1.530000 s, Elapsed simulation time: 6.627871 s
# Saving results for t = 1.540000 s, Elapsed simulation time: 6.670347 s
# Saving results for t = 1.550000 s, Elapsed simulation time: 6.714856 s
# Saving results for t = 1.560000 s, Elapsed simulation time: 6.758715 s
# Saving results for t = 1.570000 s, Elapsed simulation time: 6.802447 s
# Saving results for t = 1.580000 s, Elapsed simulation time: 6.844543 s
# Saving results for t = 1.590000 s, Elapsed simulation time: 6.886725 s
# Saving results for t = 1.600000 s, Elapsed simulation time: 6.928861 s
# Saving results for t = 1.610000 s, Elapsed simulation time: 6.971021 s
# Saving results for t = 1.620000 s, Elapsed simulation time: 7.014197 s
# Saving results for t = 1.630000 s, Elapsed simulation time: 7.057964 s
# Saving results for t = 1.640000 s, Elapsed simulation time: 7.101669 s
# Saving results for t = 1.650000 s, Elapsed simulation time: 7.145399 s
# Saving results for t = 1.660000 s, Elapsed simulation time: 7.189011 s
# Saving results for t = 1.670000 s, Elapsed simulation time: 7.232908 s
# Saving results for t = 1.680000 s, Elapsed simulation time: 7.276493 s
# Saving results for t = 1.690000 s, Elapsed simulation time: 7.320190 s
# Saving results for t = 1.700000 s, Elapsed simulation time: 7.363900 s
# Saving results for t = 1.710000 s, Elapsed simulation time: 7.407052 s
# Saving results for t = 1.720000 s, Elapsed simulation time: 7.449291 s
# Saving results for t = 1.730000 s, Elapsed simulation time: 7.491480 s
# Saving results for t = 1.740000 s, Elapsed simulation time: 7.533602 s
# Saving results for t = 1.750000 s, Elapsed simulation time: 7.575898 s
# Saving results for t = 1.760000 s, Elapsed simulation time: 7.619765 s
# Saving results for t = 1.770000 s, Elapsed simulation time: 7.663584 s
# Saving results for t = 1.780000 s, Elapsed simulation time: 7.707280 s
# Saving results for t = 1.790000 s, Elapsed simulation time: 7.750958 s
# Saving results for t = 1.800000 s, Elapsed simulation time: 7.794640 s
# Saving results for t = 1.810000 s, Elapsed simulation time: 7.838303 s
# Saving results for t = 1.820000 s, Elapsed simulation time: 7.882133 s
# Saving results for t = 1.830000 s, Elapsed simulation time: 7.924580 s
# Saving results for t = 1.840000 s, Elapsed simulation time: 7.966736 s
# Saving results for t = 1.850000 s, Elapsed simulation time: 8.008819 s
# Saving results for t = 1.860000 s, Elapsed simulation time: 8.050909 s
# Saving results for t = 1.870000 s, Elapsed simulation time: 8.093374 s
# Saving results for t = 1.880000 s, Elapsed simulation time: 8.137156 s
# Saving results for t = 1.890000 s, Elapsed simulation time: 8.181008 s
# Saving results for t = 1.900000 s, Elapsed simulation time: 8.224627 s
# Saving results for t = 3.240000 s, Elapsed simulation time: 13.998813 s
# Saving results for t = 3.250000 s, Elapsed simulation time: 14.040952 s
# Saving results for t = 3.260000 s, Elapsed simulation time: 14.083114 s
# Saving results for t = 3.270000 s, Elapsed simulation time: 14.125277 s
# Saving results for t = 3.280000 s, Elapsed simulation time: 14.167411 s
# Saving results for t = 3.290000 s, Elapsed simulation time: 14.210954 s
# Saving results for t = 3.300000 s, Elapsed simulation time: 14.254833 s
# Saving results for t = 3.310000 s, Elapsed simulation time: 14.298685 s
# Saving results for t = 3.320000 s, Elapsed simulation time: 14.342346 s
# Saving results for t = 3.330000 s, Elapsed simulation time: 14.386218 s
# Saving results for t = 3.340000 s, Elapsed simulation time: 14.429796 s
# Saving results for t = 3.350000 s, Elapsed simulation time: 14.473797 s
# Saving results for t = 3.360000 s, Elapsed simulation time: 14.517531 s
# Saving results for t = 3.370000 s, Elapsed simulation time: 14.560021 s
# Saving results for t = 3.380000 s, Elapsed simulation time: 14.602204 s
# Saving results for t = 3.390000 s, Elapsed simulation time: 14.644315 s
# Saving results for t = 3.400000 s, Elapsed simulation time: 14.686404 s
# Saving results for t = 3.410000 s, Elapsed simulation time: 14.728793 s
# Saving results for t = 3.420000 s, Elapsed simulation time: 14.772879 s
# Saving results for t = 3.430000 s, Elapsed simulation time: 14.817000 s
# Saving results for t = 3.440000 s, Elapsed simulation time: 14.860708 s
# Saving results for t = 3.450000 s, Elapsed simulation time: 14.903807 s
# Saving results for t = 3.460000 s, Elapsed simulation time: 14.947059 s
# Saving results for t = 3.470000 s, Elapsed simulation time: 14.989427 s
# Saving results for t = 3.480000 s, Elapsed simulation time: 15.031562 s
# Saving results for t = 3.490000 s, Elapsed simulation time: 15.073608 s
# Saving results for t = 3.500000 s, Elapsed simulation time: 15.117119 s
# Saving results for t = 3.510000 s, Elapsed simulation time: 15.160708 s
# Saving results for t = 3.520000 s, Elapsed simulation time: 15.204552 s
# Saving results for t = 3.530000 s, Elapsed simulation time: 15.248313 s
# Saving results for t = 3.540000 s, Elapsed simulation time: 15.292200 s
# Saving results for t = 3.550000 s, Elapsed simulation time: 15.336214 s
# Saving results for t = 3.560000 s, Elapsed simulation time: 15.379616 s
# Saving results for t = 3.570000 s, Elapsed simulation time: 15.421806 s
# Saving results for t = 3.580000 s, Elapsed simulation time: 15.465747 s
# Saving results for t = 3.590000 s, Elapsed simulation time: 15.508302 s
# Saving results for t = 3.600000 s, Elapsed simulation time: 15.550447 s
# Saving results for t = 3.610000 s, Elapsed simulation time: 15.594515 s
# Saving results for t = 3.620000 s, Elapsed simulation time: 15.638369 s
# Saving results for t = 3.630000 s, Elapsed simulation time: 15.682145 s
# Saving results for t = 3.640000 s, Elapsed simulation time: 15.725907 s
# Saving results for t = 3.650000 s, Elapsed simulation time: 15.769787 s
# Saving results for t = 3.660000 s, Elapsed simulation time: 15.812299 s
# Saving results for t = 3.670000 s, Elapsed simulation time: 15.854397 s
# Saving results for t = 3.680000 s, Elapsed simulation time: 15.896575 s
# Saving results for t = 7.900000 s, Elapsed simulation time: 34.129613 s
# Saving results for t = 7.910000 s, Elapsed simulation time: 34.172093 s
# Saving results for t = 7.920000 s, Elapsed simulation time: 34.216191 s
# Saving results for t = 7.930000 s, Elapsed simulation time: 34.259932 s
# Saving results for t = 7.940000 s, Elapsed simulation time: 34.303750 s
# Saving results for t = 7.950000 s, Elapsed simulation time: 34.347416 s
# Saving results for t = 7.960000 s, Elapsed simulation time: 34.391276 s
# Saving results for t = 7.970000 s, Elapsed simulation time: 34.434954 s
# Saving results for t = 7.980000 s, Elapsed simulation time: 34.478962 s
# Saving results for t = 7.990000 s, Elapsed simulation time: 34.521101 s
# Saving results for t = 8.000000 s, Elapsed simulation time: 34.563272 s
# Saving results for t = 8.010000 s, Elapsed simulation time: 34.606752 s
# Saving results for t = 8.020000 s, Elapsed simulation time: 34.649591 s
# Saving results for t = 8.030000 s, Elapsed simulation time: 34.692333 s
# Saving results for t = 8.040000 s, Elapsed simulation time: 34.736312 s
# Saving results for t = 8.050000 s, Elapsed simulation time: 34.780145 s
# Saving results for t = 8.060000 s, Elapsed simulation time: 34.824006 s
# Saving results for t = 8.070000 s, Elapsed simulation time: 34.866539 s
# Saving results for t = 8.080000 s, Elapsed simulation time: 34.908760 s
# Saving results for t = 8.090000 s, Elapsed simulation time: 34.950925 s
# Saving results for t = 8.100000 s, Elapsed simulation time: 34.993062 s
# Saving results for t = 8.110000 s, Elapsed simulation time: 35.035506 s
# Saving results for t = 8.120000 s, Elapsed simulation time: 35.079264 s
# Saving results for t = 8.130000 s, Elapsed simulation time: 35.123356 s
# Saving results for t = 8.140000 s, Elapsed simulation time: 35.167260 s
# Saving results for t = 8.150000 s, Elapsed simulation time: 35.211031 s
# Saving results for t = 8.160000 s, Elapsed simulation time: 35.254654 s
# Saving results for t = 8.170000 s, Elapsed simulation time: 35.298635 s
# Saving results for t = 8.180000 s, Elapsed simulation time: 35.341177 s
# Saving results for t = 8.190000 s, Elapsed simulation time: 35.383336 s
# Saving results for t = 8.200000 s, Elapsed simulation time: 35.425497 s
# Saving results for t = 8.210000 s, Elapsed simulation time: 35.467716 s
# Saving results for t = 8.220000 s, Elapsed simulation time: 35.510211 s
# Saving results for t = 8.230000 s, Elapsed simulation time: 35.554212 s
# Saving results for t = 8.240000 s, Elapsed simulation time: 35.597990 s
# Saving results for t = 8.250000 s, Elapsed simulation time: 35.642130 s
# Saving results for t = 8.260000 s, Elapsed simulation time: 35.686158 s
# Saving results for t = 8.270000 s, Elapsed simulation time: 35.730251 s
# Saving results for t = 8.280000 s, Elapsed simulation time: 35.774364 s
# Saving results for t = 8.290000 s, Elapsed simulation time: 35.818431 s
# Saving results for t = 8.300000 s, Elapsed simulation time: 35.862188 s
# Saving results for t = 8.310000 s, Elapsed simulation time: 35.906017 s
# Saving results for t = 8.320000 s, Elapsed simulation time: 35.948419 s
# Saving results for t = 8.330000 s, Elapsed simulation time: 35.991016 s
# Saving results for t = 9.230000 s, Elapsed simulation time: 39.887860 s
# Saving results for t = 9.240000 s, Elapsed simulation time: 39.931499 s
# Saving results for t = 9.250000 s, Elapsed simulation time: 39.975549 s
# Saving results for t = 9.260000 s, Elapsed simulation time: 40.019580 s
# Saving results for t = 9.270000 s, Elapsed simulation time: 40.063489 s
# Saving results for t = 9.280000 s, Elapsed simulation time: 40.107403 s
# Saving results for t = 9.290000 s, Elapsed simulation time: 40.151229 s
# Saving results for t = 9.300000 s, Elapsed simulation time: 40.193525 s
# Saving results for t = 9.310000 s, Elapsed simulation time: 40.235639 s
# Saving results for t = 9.320000 s, Elapsed simulation time: 40.277752 s
# Saving results for t = 9.330000 s, Elapsed simulation time: 40.320720 s
# Saving results for t = 9.340000 s, Elapsed simulation time: 40.363721 s
# Saving results for t = 9.350000 s, Elapsed simulation time: 40.406251 s
# Saving results for t = 9.360000 s, Elapsed simulation time: 40.448392 s
# Saving results for t = 9.370000 s, Elapsed simulation time: 40.490583 s
# Saving results for t = 9.380000 s, Elapsed simulation time: 40.532778 s
# Saving results for t = 9.390000 s, Elapsed simulation time: 40.575190 s
# Saving results for t = 9.400000 s, Elapsed simulation time: 40.618786 s
# Saving results for t = 9.410000 s, Elapsed simulation time: 40.662533 s
# Saving results for t = 9.420000 s, Elapsed simulation time: 40.706252 s
# Saving results for t = 9.430000 s, Elapsed simulation time: 40.750383 s
# Saving results for t = 9.440000 s, Elapsed simulation time: 40.794384 s
# Saving results for t = 9.450000 s, Elapsed simulation time: 40.836914 s
# Saving results for t = 9.460000 s, Elapsed simulation time: 40.879067 s
# Saving results for t = 9.470000 s, Elapsed simulation time: 40.921202 s
# Saving results for t = 9.480000 s, Elapsed simulation time: 40.963453 s
# Saving results for t = 9.490000 s, Elapsed simulation time: 41.006005 s
# Saving results for t = 9.500000 s, Elapsed simulation time: 41.050110 s
# Saving results for t = 9.510000 s, Elapsed simulation time: 41.093869 s
# Saving results for t = 9.520000 s, Elapsed simulation time: 41.137041 s
# Saving results for t = 9.530000 s, Elapsed simulation time: 41.180179 s
# Saving results for t = 9.540000 s, Elapsed simulation time: 41.222543 s
# Saving results for t = 9.550000 s, Elapsed simulation time: 41.264743 s
# Saving results for t = 9.560000 s, Elapsed simulation time: 41.307263 s
# Saving results for t = 9.570000 s, Elapsed simulation time: 41.351316 s
# Saving results for t = 9.580000 s, Elapsed simulation time: 41.394257 s
# Saving results for t = 9.590000 s, Elapsed simulation time: 41.436041 s
# Saving results for t = 9.600000 s, Elapsed simulation time: 41.478364 s
# Saving results for t = 9.610000 s, Elapsed simulation time: 41.520246 s
# Saving results for t = 9.620000 s, Elapsed simulation time: 41.562594 s
# Saving results for t = 9.630000 s, Elapsed simulation time: 41.606431 s
# Saving results for t = 9.640000 s, Elapsed simulation time: 41.650152 s
# Saving results for t = 9.650000 s, Elapsed simulation time: 41.693734 s
# Saving results for t = 9.660000 s, Elapsed simulation time: 41.737404 s
# Saving results for t = 9.670000 s, Elapsed simulation time: 41.781135 s
# Saving results for t = 9.680000 s, Elapsed simulation time: 41.823550 s
# Saving results for t = 9.690000 s, Elapsed simulation time: 41.865549 s
# Saving results for t = 9.700000 s, Elapsed simulation time: 41.907588 s
# Saving results for t = 9.710000 s, Elapsed simulation time: 41.949411 s
# Saving results for t = 9.720000 s, Elapsed simulation time: 41.991390 s
# Saving results for t = 9.730000 s, Elapsed simulation time: 42.035358 s
# Saving results for t = 9.740000 s, Elapsed simulation time: 42.078941 s
# Saving results for t = 9.750000 s, Elapsed simulation time: 42.122615 s
# Saving results for t = 9.760000 s, Elapsed simulation time: 42.166320 s
# Saving results for t = 9.770000 s, Elapsed simulation time: 42.209313 s
# Saving results for t = 9.780000 s, Elapsed simulation time: 42.251537 s
# Saving results for t = 9.790000 s, Elapsed simulation time: 42.293584 s
# Saving results for t = 9.800000 s, Elapsed simulation time: 42.335288 s
# Saving results for t = 9.810000 s, Elapsed simulation time: 42.377699 s
# Saving results for t = 9.820000 s, Elapsed simulation time: 42.421262 s
# Saving results for t = 9.830000 s, Elapsed simulation time: 42.465382 s
# Saving results for t = 9.840000 s, Elapsed simulation time: 42.510147 s
# Saving results for t = 9.850000 s, Elapsed simulation time: 42.553935 s
# Saving results for t = 9.860000 s, Elapsed simulation time: 42.597909 s
# Saving results for t = 9.870000 s, Elapsed simulation time: 42.640345 s
# Saving results for t = 9.880000 s, Elapsed simulation time: 42.682402 s
# Saving results for t = 9.890000 s, Elapsed simulation time: 42.724437 s
# Saving results for t = 9.900000 s, Elapsed simulation time: 42.766569 s
# Saving results for t = 9.910000 s, Elapsed simulation time: 42.808948 s
# Saving results for t = 9.920000 s, Elapsed simulation time: 42.852681 s
# Saving results for t = 9.930000 s, Elapsed simulation time: 42.896495 s
# Saving results for t = 9.940000 s, Elapsed simulation time: 42.939323 s
# Saving results for t = 9.950000 s, Elapsed simulation time: 42.981479 s
# Saving results for t = 9.960000 s, Elapsed simulation time: 43.023497 s
# Saving results for t = 9.970000 s, Elapsed simulation time: 43.065652 s
# Saving results for t = 9.980000 s, Elapsed simulation time: 43.107970 s
# Saving results for t = 9.990000 s, Elapsed simulation time: 43.152053 s
# Saving results for t = 10.000000 s, Elapsed simulation time: 43.195641 s
# FP velocity 1.515e+00 (mm/s)

# %%
# Sam's interactive data
# results_data extrapolation
T=results_data['T_data']
T1=T[300,:]
x=results_data['x_data'][300,:]

# define normalized curve
theta=(T1-np.min(T1))/(np.max(T1)-np.min(T1))

# interpolation function for x_d
alpha_fun = itp.interp1d(theta, x, kind='linear', assume_sorted=False, bounds_error=False, fill_value='extrapolate')
x_d = alpha_fun(0.5)
x_gs = alpha_fun(0.0001)
print(x_d)
print(x_gs)

# constants!
a=kr/(rhor*Cpr)
# Out:
# 0.0045814914813116685
# 0.005121716671014283

# %%
# plot initial curve
plt.plot(x,T1)
plt.xlabel("x")
plt.ylabel(r'$T~^oK$')
plt.title("DCPD Heat Curve Data")
# Out:
# Text(0.5, 1.0, 'DCPD Heat Curve Data')

# %%
# plot normalized curve
plt.plot(x,theta)
plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Normalized Heat Curve")
# Out:
# Text(0.5, 1.0, 'Normalized Heat Curve')

# %%
k=10000
thetaf = (1/2)*(1+np.tanh(k*(x_d-x)))

plt.plot(x,theta,label=r"DCPD Heat Curve ${\Theta}$")
plt.plot(x,thetaf,label="Heaviside Approximation ${\Theta}_{f(x)}$")
plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title(r"Normalized Approximation Function ${\Theta}_{f(x)}$")
plt.legend()

# %%
# define constants / limits
n=25
sum = 0
An = []

# functions as lambdas for scipy to play nice
fx = lambda x:((1/2)*(1+np.tanh(k*(x_d-x))))
fcos = lambda x:((1/2)*(1+np.tanh(k*(x_d-x))))*np.cos((i*np.pi*x)/L)

for i in range(n):
    if i == 0.0:
        an=(1/(L)*quad(fx,0.0,2*L)[0])
        An.append(an)
    else:
        an=(2/L)*quad(fcos,0.0,2*L)[0]
        An.append(an)
for i in range(n):
    if i == 0.0:
        sum+=An[i]
    else:
        sum+=An[i]*np.cos((i*x*np.pi)/L)

plt.plot(x,sum,'b',label="n=25")

# reset constants / limits
n = 250
sum=0
An = []

for i in range(n):
    if i == 0.0:
        an=(1/(L)*quad(fx,0.0,2*L)[0])
        An.append(an)
    else:
        an=(2/L)*quad(fcos,0.0,2*L)[0]
        An.append(an)
for i in range(n):
    if i == 0.0:
        sum+=An[i]
    else:
        sum+=An[i]*np.cos((i*x*np.pi)/L)

        
plt.plot(x,sum,'g',label="n=100")
plt.plot(x,thetaf,'r--',label="theta_F")

plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title(r"Fourier Series Approximation of ${\Theta}_{f(x)}$")
plt.legend()

# %%
Tn=0
t=0
n=250

plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

for t in range(0,11,5):
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
    plt.plot(x,Tn,label=f"t={t}s")
    
t=25
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")
    
t=100
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")

t=200
Tn = 0
for i in range(n):
    Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-(((i*np.pi)/L)**2)*a*t)
plt.plot(x,Tn,label=f"t={t}s")


plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Time Evolution of Solution")

plt.legend()

# %%
Tn=0
t=0
n=250

h=.0000005 #?
a=kr/(rhor*Cpr)
b=h/(rhor*Cpr)

lmbda = lambda i, L : (((i*np.pi)/L)**2)
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))

# plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

for t in range(0,21,):
    Tn = 0
    for i in range(n):
#        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda(i,L)*a*t)
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    plt.plot(x,Tn,label=f"t={t}s")
    



plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Time Evolution of Solution")

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %%
Tn=0
t=0
n=250

lmbda = lambda i, L : (((i*np.pi)/L)**2)
lmbda_n = lambda i, L, b, a : ((((i*np.pi)/L)**2)+(b/a))

# plt.axvline(x = x_d+0.00025, color = 'b', label = 'gap beginning')

for t in range(0,21,):
    Tn = 0
    for i in range(n):
        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda(i,L)*a*t)
#        Tn += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    plt.plot(x,Tn,label=f"t={t}s")
    



plt.xlabel("x")
plt.ylabel(r"${\Theta}$")
plt.title("Time Evolution of Solution")

plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %%
### THIS IS MY BREAK FOR BP/Ts

# %%
### END BREAK

# %%
A = 8.55e15
E = 1.1075e5
R = 8.3144621
n_g = 1.720
m_g = 0.770
c_g = 14.480
a_cg = 0.410
t_range = np.linspace(20,100,80)
alpha_o = 0.01
da_dt = []

g_a = lambda alpha : ((1-alpha)**n_g)*(alpha**m)*(1/(1+np.exp(c_g*(alpha-a_cg))))
f_a = lambda alpha : 1/(A*np.exp(-E/(R*((Hr/Cpr)*(alpha - alpha_o)+t_o)))*g_a(alpha))
for t_o in range(20+273, 100+273):
    da_dt.append(quad(f_a, alpha_o, 0.5)[0])

T_s = (np.interp(1.55,da_dt[::-1],t_range))
T_s = 100-(T_s-20)
print(T_s)

plt.axhline(1.55)
plt.axvline(T_s)
plt.yscale("log")
plt.plot(t_range,da_dt)
# Out:
# 82.64453603350003

# %%
hs = [0,0.001*rhor*Cpr,0.002*rhor*Cpr,0.003*rhor*Cpr,0.01*rhor*Cpr]
gaps = np.linspace(0,0.001,1000)
t = np.linspace(0,25,100)
n = 250

def fouriertemp(x,t,h):
    theta_xth = 0
    b = h/(rhor*Cpr)
    for i in range(n):
        theta_xth += An[i]*np.cos((i*x*np.pi)/L)*np.exp(-lmbda_n(i,L,b,a)*a*t)
    T_xth = theta_xth * (np.max(T1)-np.min(T1)) + np.min(T1) - 273
    return T_xth
"""
t_gs = []
for h in hs:
    for gap in gaps:
        x_ge = x_gs + gap
        t_gs.append(np.interp(T_s,fouriertemp(x_ge,t,h),t))
        #plt.plot(t,fouriertemp(x_ge,t,0))
    plt.plot(gaps, t_gs,label=f"h={h}")
    t_gs = []
plt.xlabel("gap length")
plt.ylabel("seconds to 82C")
plt.legend()
"""

t_gs = []
for h in hs:
    for gap in gaps:
        x_ge = x_gs + gap
        fourierinterp = itp.interp1d(fouriertemp(x_ge,t,h), t, kind='linear', assume_sorted=False, bounds_error=False, fill_value='extrapolate')
        output = fourierinterp(T_s)
        if output < 200 and output > 0:
            t_gs.append(fourierinterp(T_s))
        #plt.plot(t,fouriertemp(x_ge,t,0))
    plt.plot(gaps, t_gs,label=f"h={h}")
    t_gs = []
plt.xlabel("gap length")
plt.ylabel("seconds to 82C")
plt.legend()

"""
t_gs = []
for gap in gaps:
    x_ge = x_gs + gap
    fourierinterp = itp.interp1d(fouriertemp(x_ge,t,hs[2]), t, kind='linear', assume_sorted=False, bounds_error=False, fill_value='extrapolate')
    print(fourierinterp(T_s))
    plt.plot(t,fouriertemp(x_ge,t,hs[2]))
plt.axhline(T_s)
plt.axvline(4.886602509320188)
plt.axvline(10.030111893234157)

plt.xlabel("time")
plt.ylabel("temp")
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [499], in <cell line: 28>()
#      34             t_gs.append(fourierinterp(T_s))
#      35         #plt.plot(t,fouriertemp(x_ge,t,0))
# ---> 36     plt.plot(gaps, t_gs,label=f"h={h}")
#      37     t_gs = []
#      38 plt.xlabel("gap length")
#
# File ~/mambaforge3/envs/fenics/lib/python3.8/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/mambaforge3/envs/fenics/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/mambaforge3/envs/fenics/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/mambaforge3/envs/fenics/lib/python3.8/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1000,) and (686,)
